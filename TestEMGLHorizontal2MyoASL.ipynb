# %% [markdown]
# <a href="https://colab.research.google.com/github/michelleaeh/Dissertation/blob/master/TestEMGLHorizontal2MyoASL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Myo armband dataset from https://data.mendeley.com/datasets/wgswcr8z24/2**
#
#
# **The dataset consits of .csv files collected from two Myo armbands. The format of the files are [word_name]_[id]. The ‘word_name’ is the English translation of the American Sign Language word used and the ‘id’ is a unique identifier. The .zip for each of the above links has sub-folders for each User.**
#
# **Each file has 50 columns. They represent a sub-sampled data collection from two Myo devices worn on left and right hands of the signer. The first column is the ‘Counter’ that goes from 1 to 50.**
#
# **The following columns are of the format: [Sensor][pod/direction][left/right]. For instance the EMG reading for the first EMG pod (out of 8) on the left hand would be called EMG0R and the accelerometer reading for the Z axis on the left hand would be called: AXL**
#
# **If you use this dataset please cite the following papers:**
#
# **@inproceedings{paudyal2016sceptre,
# title={Sceptre: a pervasive, non-invasive, and programmable gesture recognition technology},
# author={Paudyal, Prajwal and Banerjee, Ayan and Gupta, Sandeep KS},
# booktitle={Proceedings of the 21st International Conference on Intelligent User Interfaces},
# pages={282--293},
# year={2016},
# organization={ACM}
# }**
#
# **@inproceedings{paudyal2017dyfav,
# title={Dyfav: Dynamic feature selection and voting for real-time recognition of fingerspelled alphabet using wearables},
# author={Paudyal, Prajwal and Lee, Junghyo and Banerjee, Ayan and Gupta, Sandeep KS},
# booktitle={Proceedings of the 22nd International Conference on Intelligent User Interfaces},
# pages={457--467},
# year={2017},
# organization={ACM}
# }**

# %% [markdown]
# **Frequency:**
#
# 50Hz sampling rate
#
# **Words:**
#
# *36 total words*
#
# allmorning, bird, blue, cantsleep, cat, colrunnynose, continuouslyforanhour, cost, day, dollar, everymorning, everynight, gold, goodnight, happy, headache, home, horse, hot, hurt, itching, large, mom, monthly, notfeelgood, orange, pizza, please, shirt, soreness, swelling, takeliquidmedicine, thatsterrible, tired, upsetstomach, wash
#
#
# **Filenames:**
#
# *849 total files*
#
# (word)_(user#)(try#)
#
#
# **Columns of files:**
#
# Counter  (1 -> 50)
#
# EMG0L -> EMG7L  (EMG sensor readings)
#
# AXL, AYL, AZL  (accelerometer readings)
#
# GXL, GYL, GZL  (gyroscope readings)
#
# ORL, OPL, OYL  (magnetometer readings?)
#
# EMG0R -> EMG7R  (EMG sensor readings)
#
# AXR, AYR, AZR  (accelerometer readings)
#
# GXR, GYR, GZR  (gyroscope readings)
#
# ORR, OPR, OYR  (magnetometer readings?)
#
# features=['EMG0L', 'EMG1L', 'EMG2L', 'EMG3L', 'EMG4L', 'EMG5L', 'EMG6L', 'EMG7L', 'AXL', 'AYL', 'AZL', 'GXL', 'GYL', 'GZL', 'ORL', 'OPL', 'OYL', 'EMG0R', 'EMG1R', 'EMG2R', 'EMG3R', 'EMG4R', 'EMG5R', 'EMG6R', 'EMG7R', 'AXR', 'AYR', 'AZR', 'GXR', 'GYR', 'GZR', 'ORR', 'OPR', 'OYR']
#
#
# **Size of files:**
#
# All files are 50 rows x 35 columns except continuouslyforanhour_22.csv, headache_52.csv, home_61.csv, and mom_82.csv which are 101 rows x 35 columns

# %% [markdown]
# **Steps:**
#
# 1. Combine files
# 2. Normalize or standardize matrix
# 3. Apply Butterworth
# 4. Apply PCA
# 5. Input to SVM

# %%
import matplotlib.pyplot as plt
import numpy as np
import os.path
import pandas as pd
import scipy as sp
import warnings

from google.colab import files
from mpl_toolkits import mplot3d
from scipy import signal
from scipy.io import loadmat
from sklearn import metrics
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from zipfile import ZipFile

# Import zip containing all files
file_name = "/content/2MyoASL.zip"

# Extract all files from zip
with ZipFile(file_name, 'r') as zip:
  zip.extractall()

# %%
# Generate matrices for all combinations of sensors (E=3, A=5, G=7, O=11)
products=[3, 5, 7, 11, 15, 21, 33, 35, 55, 77, 105, 165, 231, 385, 1155]
comb=['e', 'a', 'g', 'o', 'ea', 'eg', 'eo', 'ag', 'ao', 'go', 'eag', 'eao', 'ego', 'ago', 'eago']
emg=['EMG0L', 'EMG1L', 'EMG2L', 'EMG3L', 'EMG4L', 'EMG5L', 'EMG6L', 'EMG7L', 
    'EMG0R', 'EMG1R', 'EMG2R', 'EMG3R', 'EMG4R', 'EMG5R', 'EMG6R', 'EMG7R']
acc=['AXL', 'AYL', 'AZL', 'AXR', 'AYR', 'AZR']
gyro=['GXL', 'GYL', 'GZL', 'GXR', 'GYR', 'GZR']
ori=['ORL', 'OPL', 'OYL', 'ORR', 'OPR', 'OYR']

# Initialization of counters
words=['allmorning', 'bird', 'blue', 'cantsleep', 'cat', 'coldrunnynose', 'continuouslyforanhour', 'cost', 'day', 
       'dollar', 'everymorning', 'everynight', 'gold', 'goodnight', 'happy', 'headache', 'home', 'horse', 'hot', 
       'hurt', 'itching', 'large', 'mom', 'monthly', 'notfeelgood', 'orange', 'pizza', 'please', 'shirt', 
       'soreness', 'swelling', 'takeliquidmedicine', 'thatsterrible', 'tired', 'upsetstomach', 'wash']
colnames=['EMG0L', 'EMG1L', 'EMG2L', 'EMG3L', 'EMG4L', 'EMG5L', 'EMG6L', 'EMG7L', 'AXL', 'AYL', 'AZL', 'GXL', 'GYL', 'GZL', 'ORL', 'OPL', 'OYL', 
          'EMG0R', 'EMG1R', 'EMG2R', 'EMG3R', 'EMG4R', 'EMG5R', 'EMG6R', 'EMG7R', 'AXR', 'AYR', 'AZR', 'GXR', 'GYR', 'GZR', 'ORR', 'OPR', 'OYR']
lengths=np.zeros(849, dtype=int)
reps=np.zeros(36,dtype=int)
headers=np.empty(1701, dtype=object)
features=np.zeros(15)
target=np.zeros(15)
matrix=np.zeros(1)

fn=np.arange(1701)
wordnum=-1
counter=-1
num=0
n=0

# %%
# Combine all files
for w in words:
  repcount=0
  wordnum+=1

  for i in range (10, 120):
    path='/content/2MyoASL/' + w + '_' + str(i) + '.csv'

    if os.path.exists(path)==True:
      counter+=1
      repcount+=1
      trial=pd.read_csv(path)

      trial.reset_index(drop=True)
      
      # Assign word number to one row
      row=np.zeros(1)
      for t in range(35):
        if t==0:
          row[0]=wordnum
        else:
          sensor=trial.iloc[0:50,t].values
          sensor.reshape([1,50])
          row=np.concatenate((row, sensor))
      prev=row
      
      # Combine all trials
      if counter==0:
        matrix=prev
      else:
        matrix=np.concatenate([matrix,prev])

# Create header name array
headers[0]='Word'
for c in colnames:
  for t in range(50):
    num+=1
    headers[num]=c

# Give format to final matrix 
matrix=matrix.reshape([849,1701])
matrix=pd.DataFrame(matrix, columns=headers)
matrix=matrix.iloc[:,0:401]
print(matrix)
# Out:
#      Word  EMG0L  EMG0L  EMG0L  EMG0L  ...  EMG7L  EMG7L  EMG7L  EMG7L  EMG7L
# 0     0.0    0.0    0.0   -3.0   -1.0  ...   -1.0   -6.0   -7.0    2.0    2.0
# 1     0.0    0.0    0.0    4.0   -2.0  ...    1.0   -1.0   26.0  -11.0  -10.0
# 2     0.0    0.0    0.0   -8.0   -1.0  ...   -4.0   -6.0    1.0   -3.0   -3.0
# 3     0.0    0.0    0.0   -1.0  -19.0  ...   -9.0    9.0   -3.0    1.0    0.0
# 4     0.0    0.0    0.0    1.0  -16.0  ...   -2.0    0.0    3.0   -8.0    0.0
# ..    ...    ...    ...    ...    ...  ...    ...    ...    ...    ...    ...
# 844  35.0    0.0    0.0   -2.0    0.0  ...    0.0    9.0   -7.0    0.0    0.0
# 845  35.0    0.0    0.0    2.0   -8.0  ...   -1.0    0.0   -1.0   -2.0   -1.0
# 846  35.0    0.0    0.0   -8.0   26.0  ...    6.0  -14.0    1.0    1.0    1.0
# 847  35.0    0.0    0.0   -1.0   21.0  ...    0.0    1.0   -1.0   -1.0   -3.0
# 848  35.0    0.0    0.0    8.0  -19.0  ...   -2.0    1.0   -3.0   -1.0    0.0
#
# [849 rows x 401 columns]

# %%
attempt=matrix
print(attempt)
attempt.to_csv(path_or_buf='/content/attempt.csv')
# Out:
#      Word  EMG0L  EMG0L  EMG0L  EMG0L  ...  EMG7L  EMG7L  EMG7L  EMG7L  EMG7L
# 0     0.0    0.0    0.0   -3.0   -1.0  ...   -1.0   -6.0   -7.0    2.0    2.0
# 1     0.0    0.0    0.0    4.0   -2.0  ...    1.0   -1.0   26.0  -11.0  -10.0
# 2     0.0    0.0    0.0   -8.0   -1.0  ...   -4.0   -6.0    1.0   -3.0   -3.0
# 3     0.0    0.0    0.0   -1.0  -19.0  ...   -9.0    9.0   -3.0    1.0    0.0
# 4     0.0    0.0    0.0    1.0  -16.0  ...   -2.0    0.0    3.0   -8.0    0.0
# ..    ...    ...    ...    ...    ...  ...    ...    ...    ...    ...    ...
# 844  35.0    0.0    0.0   -2.0    0.0  ...    0.0    9.0   -7.0    0.0    0.0
# 845  35.0    0.0    0.0    2.0   -8.0  ...   -1.0    0.0   -1.0   -2.0   -1.0
# 846  35.0    0.0    0.0   -8.0   26.0  ...    6.0  -14.0    1.0    1.0    1.0
# 847  35.0    0.0    0.0   -1.0   21.0  ...    0.0    1.0   -1.0   -1.0   -3.0
# 848  35.0    0.0    0.0    8.0  -19.0  ...   -2.0    1.0   -3.0   -1.0    0.0
#
# [849 rows x 401 columns]

# %%
# Eliminate unnecessary columns to create combinatory matrices
for v in products:
  m=matrix
  """
  if v%3!=0:
    m=m.drop(emg,1)
  if v%5!=0:
    m=m.drop(acc,1)
  if v%7!=0:
    m=m.drop(gyro,1)
  if v%11!=0:
    m=m.drop(ori,1)
  """
  products[n]=m
  exec(comb[n]+"=products[n]")
  n+=1
  
  # Normalize and Standardize each of the 15 matrices
  # Separate features from target values
  x = m.iloc[:, m.columns!='Word'].values   # Features
 
  ## Normalize features so that each column is between 0 and 1
  norm_matrix=(m-m.min())/(m.max()-m.min())
  exec("norm_matrix_"+comb[n-1]+"=pd.DataFrame(norm_matrix)")
  exec("norm_matrix_"+comb[n-1]+"=norm_matrix_"+comb[n-1]+".dropna(axis=1)")

 # Standardize features with mean=0 and deviation=1
  standardized_matrix=StandardScaler().fit_transform(x)
  exec("standardized_matrix_"+comb[n-1]+"=pd.DataFrame(standardized_matrix)")
"""
  # Save data frames as csv files
  #matrix.to_csv(path_or_buf='/content/matrix_'+comb[n-1]+'.csv')
  exec("norm_matrix_"+comb[n-1]+".to_csv(path_or_buf='/content/normmatrix_'+comb[n-1]+'.csv')")
#  exec("normalized_matrix_"+comb[n-1]+".to_csv(path_or_buf='/content/normalizedmatrix_'+comb[n-1]+'.csv')")
  exec("standardized_matrix_"+comb[n-1]+".to_csv(path_or_buf='/content/standardizedmatrix_'+comb[n-1]+'.csv')")
"""
print(norm_matrix_e)
# Out:
#      Word     EMG0L     EMG0L     EMG0L  ...     EMG7L     EMG7L     EMG7L     EMG7L
# 0     0.0  0.321429  0.388889  0.673759  ...  0.677165  0.541667  0.253012  0.500000
# 1     0.0  0.321429  0.432099  0.666667  ...  0.716535  1.000000  0.174699  0.363636
# 2     0.0  0.321429  0.358025  0.673759  ...  0.677165  0.652778  0.222892  0.443182
# 3     0.0  0.321429  0.401235  0.546099  ...  0.795276  0.597222  0.246988  0.477273
# 4     0.0  0.321429  0.413580  0.567376  ...  0.724409  0.680556  0.192771  0.477273
# ..    ...       ...       ...       ...  ...       ...       ...       ...       ...
# 844   1.0  0.321429  0.395062  0.680851  ...  0.795276  0.541667  0.240964  0.477273
# 845   1.0  0.321429  0.419753  0.624113  ...  0.724409  0.625000  0.228916  0.465909
# 846   1.0  0.321429  0.358025  0.865248  ...  0.614173  0.652778  0.246988  0.488636
# 847   1.0  0.321429  0.401235  0.829787  ...  0.732283  0.625000  0.234940  0.443182
# 848   1.0  0.321429  0.456790  0.546099  ...  0.732283  0.597222  0.234940  0.477273
#
# [849 rows x 393 columns]

# %%
# Replace wordnum with word
for r in range(849):
  wn=int(35*norm_matrix_e.iloc[r,0])
  norm_matrix_e.iloc[r,0]=words[wn]
nmatrix=norm_matrix_e
print(nmatrix)
nmatrix.to_csv(path_or_buf='/content/nmatrix.csv')
# Out:
#            Word     EMG0L     EMG0L  ...     EMG7L     EMG7L     EMG7L
# 0    allmorning  0.321429  0.388889  ...  0.541667  0.253012  0.500000
# 1    allmorning  0.321429  0.432099  ...  1.000000  0.174699  0.363636
# 2    allmorning  0.321429  0.358025  ...  0.652778  0.222892  0.443182
# 3    allmorning  0.321429  0.401235  ...  0.597222  0.246988  0.477273
# 4    allmorning  0.321429  0.413580  ...  0.680556  0.192771  0.477273
# ..          ...       ...       ...  ...       ...       ...       ...
# 844        wash  0.321429  0.395062  ...  0.541667  0.240964  0.477273
# 845        wash  0.321429  0.419753  ...  0.625000  0.228916  0.465909
# 846        wash  0.321429  0.358025  ...  0.652778  0.246988  0.488636
# 847        wash  0.321429  0.401235  ...  0.625000  0.234940  0.443182
# 848        wash  0.321429  0.456790  ...  0.597222  0.234940  0.477273
#
# [849 rows x 393 columns]

# %%
"""
# Butterworth
#high = 20/(1000/2)
#low = 450/(1000/2)
high = 1/(50/2)
low = 23/(50/2)

b, a = sp.signal.butter(4, [high,low], btype='bandpass')

for r in emg:
  if r in norm_matrix_e:
    norm_matrix_e[[r]]
    # process EMG signal: filter EMG
    emg_filtered = sp.signal.lfilter(b, a, norm_matrix_e[[r]])
    norm_matrix_e[[r]]=emg_filtered
    """
# Out:
# "\n# Butterworth\n#high = 20/(1000/2)\n#low = 450/(1000/2)\nhigh = 1/(50/2)\nlow = 23/(50/2)\n\nb, a = sp.signal.butter(4, [high,low], btype='bandpass')\n\nfor r in emg:\n  if r in norm_matrix_e:\n    norm_matrix_e[[r]]\n    # process EMG signal: filter EMG\n    emg_filtered = sp.signal.lfilter(b, a, norm_matrix_e[[r]])\n    norm_matrix_e[[r]]=emg_filtered\n    "

# %%
buttermatrix=norm_matrix_e
print(buttermatrix)
# Out:
#            Word     EMG0L     EMG0L  ...     EMG7L     EMG7L     EMG7L
# 0    allmorning  0.321429  0.388889  ...  0.541667  0.253012  0.500000
# 1    allmorning  0.321429  0.432099  ...  1.000000  0.174699  0.363636
# 2    allmorning  0.321429  0.358025  ...  0.652778  0.222892  0.443182
# 3    allmorning  0.321429  0.401235  ...  0.597222  0.246988  0.477273
# 4    allmorning  0.321429  0.413580  ...  0.680556  0.192771  0.477273
# ..          ...       ...       ...  ...       ...       ...       ...
# 844        wash  0.321429  0.395062  ...  0.541667  0.240964  0.477273
# 845        wash  0.321429  0.419753  ...  0.625000  0.228916  0.465909
# 846        wash  0.321429  0.358025  ...  0.652778  0.246988  0.488636
# 847        wash  0.321429  0.401235  ...  0.625000  0.234940  0.443182
# 848        wash  0.321429  0.456790  ...  0.597222  0.234940  0.477273
#
# [849 rows x 393 columns]

# %% [markdown]
# **Combinations of steps for classification**

# %%
# Directly to SVM
x = attempt.iloc[:, attempt.columns!='Word'].values   # Features
y = attempt.loc[:,'Word'].values     # Target
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.6)

clf = SVC()
clf.fit(x_train, y_train)
print ('score', clf.score(x_test, y_test))
y_pred=clf.predict(x_test)
print ('pred label', y_pred)
print('length',len(clf.predict(x_test)))

# Confusion matrix
plot_confusion_matrix(clf, x_test, y_test,
                                 cmap=plt.cm.Blues)
plt.figure(figsize=(50,50))
plt.show()

#print(classification_report(y_test, y_pred, target_names=words))
directresults=classification_report(y_test, y_pred, target_names=words)
# Out:
# score 0.08431372549019608
# pred label [18. 28. 21. 18. 13. 18. 28. 21. 28. 28. 18. 18. 18. 13. 21. 18. 18. 18.
#  18. 18. 18. 18. 21. 18. 18. 21. 28. 18. 21. 18. 18. 13.  7. 18. 21. 21.
#  18. 18. 13. 18. 18. 28. 13. 21. 18. 18. 18. 18. 18. 21. 18. 18. 21. 21.
#  21. 13. 18. 18. 28. 28. 18. 18. 28. 13. 18. 28. 28. 13. 18. 18. 18. 28.
#  21. 21. 18. 21. 21. 18. 13. 21. 18. 21. 18. 18. 18. 28. 13. 13. 28. 18.
#  18. 28. 28. 18. 18. 21. 18. 28. 18. 18. 13. 21. 18. 28. 18. 21. 18. 18.
#  21.  7. 18. 28. 13. 18. 18. 28. 18. 13. 18. 13. 18. 21. 18. 18. 18. 21.
#  18. 18. 13. 13. 13. 28. 18. 21. 18. 28. 18. 18. 21. 21. 18. 18. 13. 21.
#  21. 18. 18. 18. 18. 13. 13. 28. 21. 18. 13. 18. 13. 21. 18. 18. 13. 18.
#  13.  7. 18. 18. 21. 18. 18. 28. 18. 18. 18. 18. 13. 18. 13. 18. 21. 18.
#  28. 21. 21. 18. 13. 18. 21. 13. 21. 18. 21. 21. 21. 21. 13. 18. 21. 18.
#  18. 28. 18. 21. 21. 13. 18. 21. 21. 18. 18. 18. 18. 13. 13. 13. 13. 13.
#  13.  7. 18. 18. 18. 13. 21. 18. 18. 21. 18. 18. 18. 18. 18. 18. 18. 18.
#  21. 21. 18. 18. 18. 21. 21. 18. 21. 21. 18. 18. 18. 18. 18. 13. 18. 21.
#  28. 18. 18. 18. 28. 18. 21. 18. 28. 28. 13. 18. 13. 18. 18. 18. 21. 18.
#  13. 28. 18. 28. 18. 28. 18. 18. 18. 18. 18. 28. 18. 28. 18. 13. 21. 18.
#  13. 18. 18. 21. 18. 18. 28. 13. 13. 18. 18. 21. 13. 28. 28. 21. 28. 21.
#  18. 18. 18. 18. 28. 18. 18. 18. 18. 18. 18. 18. 18. 28. 28. 28. 18. 18.
#  21. 21. 18. 18. 18. 28. 18. 28. 18. 18. 28. 13. 21. 21. 13. 21. 28. 21.
#  21. 18. 21. 28. 13. 18. 28.  7. 21. 18. 28. 18. 28. 13. 18. 18. 21. 13.
#  21. 21. 21. 18. 18. 18. 28. 18. 21. 18. 13. 18. 18. 13. 18. 21. 18. 21.
#  13. 18. 28. 13. 13. 18. 28. 18. 18. 13. 18. 28. 18. 18. 18. 18. 21. 13.
#   7. 28. 18. 21. 18. 21. 18. 18. 18. 18. 21. 21. 18. 18. 13. 28. 18. 13.
#  18. 13. 18. 18. 18. 21. 13. 18. 18. 28. 18. 18. 13. 28. 21. 18. 18. 13.
#  21. 28. 18. 18. 13. 18. 18. 28. 21. 18. 18. 21. 18. 13. 21. 18. 28. 28.
#  13. 13. 18. 13. 21. 13. 18. 18. 18. 18. 18. 28. 28. 13. 21. 18. 28. 18.
#  18. 18. 18. 18. 21. 28. 13. 28. 18. 18. 21. 18. 28. 28.  7. 21. 18. 13.
#  18. 18. 13. 21. 13. 28. 28. 18. 28. 18. 28. 21. 18. 13. 21. 21. 28. 18.
#  21. 18. 18. 18. 13. 18.]
# length 510
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Normalized to SVM
x = nmatrix.iloc[:, nmatrix.columns!='Word'].values   # Features
y = nmatrix.loc[:,'Word'].values     # Target

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.6)

clf = SVC()
clf.fit(x_train, y_train)
print ('score', clf.score(x_test, y_test))
y_pred=clf.predict(x_test)
print ('pred label', y_pred)
print('length',len(clf.predict(x_test)))

# Confusion matrix
plot_confusion_matrix(clf, x_test, y_test,
                                 cmap=plt.cm.Blues)
plt.figure(figsize=(50,50))
plt.show()

#print(classification_report(y_test, y_pred, target_names=words))
normresults=classification_report(y_test, y_pred, target_names=words)
# Out:
# score 0.06862745098039216
# pred label ['cost' 'cost' 'happy' 'cost' 'cost' 'happy' 'cost' 'blue' 'happy' 'blue'
#  'blue' 'large' 'cost' 'cost' 'blue' 'large' 'cost' 'cost' 'cost' 'blue'
#  'blue' 'cost' 'cost' 'blue' 'blue' 'cost' 'cost' 'large' 'blue' 'blue'
#  'blue' 'blue' 'blue' 'blue' 'cost' 'blue' 'blue' 'blue' 'blue' 'blue'
#  'blue' 'blue' 'cost' 'blue' 'blue' 'cost' 'blue' 'large' 'blue' 'happy'
#  'blue' 'cost' 'happy' 'cost' 'blue' 'cost' 'blue' 'blue' 'blue' 'cost'
#  'cost' 'cost' 'cost' 'cost' 'cost' 'cost' 'large' 'blue' 'cost' 'blue'
#  'happy' 'cost' 'blue' 'cost' 'cost' 'blue' 'blue' 'blue' 'blue' 'cost'
#  'blue' 'blue' 'blue' 'cost' 'large' 'blue' 'cost' 'blue' 'blue' 'blue'
#  'blue' 'blue' 'large' 'blue' 'cost' 'blue' 'happy' 'cost' 'blue' 'cost'
#  'blue' 'cost' 'blue' 'cost' 'blue' 'blue' 'blue' 'blue' 'blue' 'cost'
#  'blue' 'cost' 'blue' 'cost' 'cost' 'cost' 'large' 'blue' 'blue' 'happy'
#  'cost' 'blue' 'cost' 'blue' 'blue' 'cost' 'blue' 'blue' 'blue' 'blue'
#  'cost' 'blue' 'blue' 'blue' 'large' 'blue' 'blue' 'blue' 'cost' 'large'
#  'blue' 'blue' 'cost' 'cost' 'cost' 'blue' 'cost' 'blue' 'blue' 'cost'
#  'blue' 'happy' 'cost' 'cost' 'blue' 'blue' 'cost' 'cost' 'blue' 'blue'
#  'large' 'large' 'happy' 'large' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue'
#  'cost' 'cost' 'blue' 'blue' 'cost' 'happy' 'cost' 'cost' 'cost' 'cost'
#  'blue' 'cost' 'cost' 'blue' 'cost' 'blue' 'happy' 'blue' 'cost' 'blue'
#  'cost' 'cost' 'cost' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'cost'
#  'cost' 'blue' 'blue' 'cost' 'cost' 'blue' 'cost' 'happy' 'cost' 'blue'
#  'blue' 'cost' 'blue' 'cost' 'blue' 'blue' 'blue' 'blue' 'cost' 'cost'
#  'cost' 'cost' 'blue' 'cost' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue'
#  'blue' 'blue' 'cost' 'blue' 'cost' 'blue' 'cost' 'blue' 'large' 'cost'
#  'blue' 'blue' 'cost' 'blue' 'blue' 'cost' 'blue' 'blue' 'blue' 'blue'
#  'cost' 'blue' 'cost' 'large' 'large' 'happy' 'blue' 'blue' 'cost' 'cost'
#  'cost' 'blue' 'cost' 'cost' 'blue' 'cost' 'blue' 'cost' 'blue' 'blue'
#  'cost' 'blue' 'blue' 'blue' 'cost' 'blue' 'blue' 'happy' 'cost' 'blue'
#  'cost' 'cost' 'large' 'blue' 'cost' 'blue' 'blue' 'blue' 'large' 'cost'
#  'cost' 'cost' 'large' 'large' 'large' 'cost' 'happy' 'blue' 'cost' 'cost'
#  'blue' 'cost' 'cost' 'cost' 'blue' 'cost' 'cost' 'large' 'blue' 'cost'
#  'blue' 'blue' 'blue' 'blue' 'cost' 'cost' 'cost' 'large' 'cost' 'blue'
#  'blue' 'blue' 'blue' 'blue' 'large' 'large' 'blue' 'blue' 'blue' 'cost'
#  'large' 'cost' 'blue' 'blue' 'large' 'cost' 'cost' 'blue' 'blue' 'blue'
#  'blue' 'blue' 'blue' 'large' 'large' 'blue' 'blue' 'blue' 'blue' 'blue'
#  'happy' 'blue' 'cost' 'blue' 'large' 'blue' 'blue' 'blue' 'blue' 'blue'
#  'large' 'cost' 'cost' 'blue' 'blue' 'blue' 'blue' 'happy' 'blue' 'cost'
#  'large' 'blue' 'blue' 'large' 'blue' 'happy' 'blue' 'large' 'cost' 'blue'
#  'blue' 'blue' 'cost' 'large' 'happy' 'blue' 'cost' 'blue' 'large' 'cost'
#  'blue' 'cost' 'blue' 'blue' 'blue' 'blue' 'cost' 'blue' 'cost' 'cost'
#  'blue' 'cost' 'blue' 'blue' 'blue' 'blue' 'blue' 'happy' 'cost' 'cost'
#  'cost' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'cost'
#  'blue' 'blue' 'cost' 'blue' 'blue' 'blue' 'cost' 'blue' 'happy' 'happy'
#  'blue' 'cost' 'blue' 'large' 'blue' 'cost' 'blue' 'cost' 'blue' 'cost'
#  'blue' 'blue' 'blue' 'cost' 'blue' 'blue' 'cost' 'blue' 'blue' 'cost'
#  'blue' 'happy' 'blue' 'blue' 'blue' 'blue' 'cost' 'cost' 'blue' 'blue'
#  'blue' 'blue' 'blue' 'cost' 'large' 'blue' 'blue' 'blue' 'cost' 'blue'
#  'large' 'blue' 'blue' 'large' 'blue' 'large' 'blue' 'blue' 'cost' 'blue'
#  'blue' 'blue' 'blue' 'blue' 'cost' 'cost' 'blue' 'cost' 'cost' 'blue'
#  'blue' 'cost' 'blue' 'cost' 'happy' 'blue' 'cost' 'blue' 'cost' 'cost'
#  'blue' 'cost' 'blue' 'cost' 'blue' 'cost' 'blue' 'blue' 'cost' 'blue']
# length 510
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Normalized, Butterworth to SVM
x = buttermatrix.iloc[:, buttermatrix.columns!='Word'].values   # Features
y = buttermatrix.loc[:,'Word'].values     # Target

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.6)

clf = SVC()
clf.fit(x_train, y_train)
print ('score', clf.score(x_test, y_test))
y_pred=clf.predict(x_test)
print ('pred label', y_pred)
print('length',len(clf.predict(x_test)))

# Confusion matrix
plot_confusion_matrix(clf, x_test, y_test,
                                 cmap=plt.cm.Blues)
plt.figure(figsize=(50,50))
plt.show()

#print(classification_report(y_test, y_pred, target_names=words))
butterresults=classification_report(y_test, y_pred, target_names=words)
# Out:
# score 0.047058823529411764
# pred label ['dollar' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'shirt'
#  'goodnight' 'dollar' 'goodnight' 'goodnight' 'goodnight' 'shirt'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'dollar' 'shirt' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'shirt' 'goodnight' 'goodnight' 'shirt' 'shirt'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'shirt' 'shirt'
#  'goodnight' 'goodnight' 'shirt' 'goodnight' 'goodnight' 'goodnight'
#  'shirt' 'goodnight' 'goodnight' 'goodnight' 'dollar' 'goodnight' 'dollar'
#  'goodnight' 'goodnight' 'dollar' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'shirt'
#  'goodnight' 'goodnight' 'shirt' 'goodnight' 'shirt' 'dollar' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'shirt' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'shirt' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'shirt' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'shirt' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'shirt' 'goodnight' 'shirt' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'shirt' 'dollar' 'goodnight' 'dollar' 'goodnight'
#  'goodnight' 'shirt' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'dollar' 'goodnight' 'goodnight' 'shirt' 'goodnight' 'shirt'
#  'shirt' 'shirt' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'shirt' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'shirt'
#  'shirt' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'shirt' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'shirt' 'goodnight' 'goodnight'
#  'goodnight' 'shirt' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'shirt' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'shirt' 'goodnight' 'goodnight'
#  'shirt' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'shirt' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'dollar' 'shirt'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'shirt' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'shirt' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'shirt' 'shirt' 'goodnight' 'goodnight' 'shirt' 'goodnight' 'goodnight'
#  'goodnight' 'shirt' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'shirt' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'shirt' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'dollar' 'goodnight' 'goodnight' 'goodnight'
#  'dollar' 'goodnight' 'goodnight' 'goodnight' 'shirt' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'shirt' 'dollar'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'shirt' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'shirt' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'shirt' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'shirt' 'goodnight' 'shirt' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'shirt'
#  'goodnight' 'shirt' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'shirt' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'shirt' 'goodnight' 'goodnight' 'shirt' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'shirt' 'goodnight'
#  'shirt' 'goodnight' 'goodnight' 'goodnight' 'shirt' 'goodnight' 'shirt'
#  'goodnight' 'goodnight' 'goodnight' 'shirt' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'shirt' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'shirt' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'shirt' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'shirt' 'goodnight' 'shirt' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'dollar' 'goodnight' 'shirt' 'goodnight' 'shirt'
#  'goodnight' 'goodnight' 'goodnight' 'shirt' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'shirt' 'goodnight'
#  'goodnight' 'goodnight' 'shirt' 'goodnight' 'shirt' 'shirt' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'dollar' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'shirt' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'dollar' 'shirt' 'shirt' 'goodnight' 'goodnight'
#  'shirt' 'shirt' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'dollar' 'shirt'
#  'goodnight' 'shirt' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'dollar' 'goodnight' 'goodnight' 'goodnight' 'shirt'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'shirt' 'shirt'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'dollar']
# length 510
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# PCA for norm_matrix
x = norm_matrix_e.iloc[:, norm_matrix_e.columns!='Word'].values   # Features
y = norm_matrix_e.loc[:,'Word'].values     # Target
print(norm_matrix_e)
print(x)
print(y)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.6)

pca = PCA(n_components=300)
pca.fit(x_train)
x_t_train = pca.transform(x_train)
x_t_test = pca.transform(x_test)

#### plot
print("Normalized matrix")
print(pca.explained_variance_ratio_)
print(pca.singular_values_)
plt.figure()
plt.bar(fn[:300],pca.explained_variance_ratio_)
plt.show()
plt.bar(fn[:300],pca.singular_values_)
plt.show()
# Out:
#            Word     EMG0L     EMG0L  ...     EMG7L     EMG7L     EMG7L
# 0    allmorning  0.321429  0.388889  ...  0.541667  0.253012  0.500000
# 1    allmorning  0.321429  0.432099  ...  1.000000  0.174699  0.363636
# 2    allmorning  0.321429  0.358025  ...  0.652778  0.222892  0.443182
# 3    allmorning  0.321429  0.401235  ...  0.597222  0.246988  0.477273
# 4    allmorning  0.321429  0.413580  ...  0.680556  0.192771  0.477273
# ..          ...       ...       ...  ...       ...       ...       ...
# 844        wash  0.321429  0.395062  ...  0.541667  0.240964  0.477273
# 845        wash  0.321429  0.419753  ...  0.625000  0.228916  0.465909
# 846        wash  0.321429  0.358025  ...  0.652778  0.246988  0.488636
# 847        wash  0.321429  0.401235  ...  0.625000  0.234940  0.443182
# 848        wash  0.321429  0.456790  ...  0.597222  0.234940  0.477273
#
# [849 rows x 393 columns]
# [[0.32142857 0.38888889 0.67375887 ... 0.54166667 0.25301205 0.5       ]
#  [0.32142857 0.43209877 0.66666667 ... 1.         0.1746988  0.36363636]
#  [0.32142857 0.35802469 0.67375887 ... 0.65277778 0.22289157 0.44318182]
#  ...
#  [0.32142857 0.35802469 0.86524823 ... 0.65277778 0.24698795 0.48863636]
#  [0.32142857 0.40123457 0.82978723 ... 0.625      0.23493976 0.44318182]
#  [0.32142857 0.45679012 0.54609929 ... 0.59722222 0.23493976 0.47727273]]
# ['allmorning' 'allmorning' 'allmorning' 'allmorning' 'allmorning'
#  'allmorning' 'allmorning' 'allmorning' 'allmorning' 'allmorning'
#  'allmorning' 'allmorning' 'allmorning' 'allmorning' 'allmorning'
#  'allmorning' 'allmorning' 'allmorning' 'allmorning' 'bird' 'bird' 'bird'
#  'bird' 'bird' 'bird' 'bird' 'bird' 'bird' 'bird' 'bird' 'bird' 'bird'
#  'bird' 'bird' 'bird' 'bird' 'bird' 'bird' 'bird' 'bird' 'bird' 'bird'
#  'bird' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue'
#  'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue'
#  'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue' 'blue'
#  'blue' 'blue' 'blue' 'cantsleep' 'cantsleep' 'cantsleep' 'cantsleep'
#  'cantsleep' 'cantsleep' 'cantsleep' 'cantsleep' 'cantsleep' 'cantsleep'
#  'cantsleep' 'cantsleep' 'cantsleep' 'cantsleep' 'cantsleep' 'cantsleep'
#  'cantsleep' 'cantsleep' 'cantsleep' 'cantsleep' 'cat' 'cat' 'cat' 'cat'
#  'cat' 'cat' 'cat' 'cat' 'cat' 'cat' 'cat' 'cat' 'cat' 'cat' 'cat' 'cat'
#  'cat' 'cat' 'cat' 'cat' 'cat' 'cat' 'cat' 'cat' 'coldrunnynose'
#  'coldrunnynose' 'coldrunnynose' 'coldrunnynose' 'coldrunnynose'
#  'coldrunnynose' 'coldrunnynose' 'coldrunnynose' 'coldrunnynose'
#  'coldrunnynose' 'coldrunnynose' 'coldrunnynose' 'coldrunnynose'
#  'coldrunnynose' 'coldrunnynose' 'coldrunnynose' 'coldrunnynose'
#  'coldrunnynose' 'coldrunnynose' 'coldrunnynose' 'continuouslyforanhour'
#  'continuouslyforanhour' 'continuouslyforanhour' 'continuouslyforanhour'
#  'continuouslyforanhour' 'continuouslyforanhour' 'continuouslyforanhour'
#  'continuouslyforanhour' 'continuouslyforanhour' 'continuouslyforanhour'
#  'continuouslyforanhour' 'continuouslyforanhour' 'continuouslyforanhour'
#  'continuouslyforanhour' 'continuouslyforanhour' 'continuouslyforanhour'
#  'continuouslyforanhour' 'continuouslyforanhour' 'continuouslyforanhour'
#  'cost' 'cost' 'cost' 'cost' 'cost' 'cost' 'cost' 'cost' 'cost' 'cost'
#  'cost' 'cost' 'cost' 'cost' 'cost' 'cost' 'cost' 'cost' 'cost' 'cost'
#  'cost' 'cost' 'cost' 'cost' 'cost' 'cost' 'cost' 'cost' 'cost' 'cost'
#  'cost' 'day' 'day' 'day' 'day' 'day' 'day' 'day' 'day' 'day' 'day' 'day'
#  'day' 'day' 'day' 'day' 'day' 'day' 'day' 'day' 'day' 'day' 'day' 'day'
#  'day' 'dollar' 'dollar' 'dollar' 'dollar' 'dollar' 'dollar' 'dollar'
#  'dollar' 'dollar' 'dollar' 'dollar' 'dollar' 'dollar' 'dollar' 'dollar'
#  'dollar' 'dollar' 'dollar' 'dollar' 'dollar' 'dollar' 'dollar' 'dollar'
#  'dollar' 'dollar' 'dollar' 'dollar' 'dollar' 'dollar' 'everymorning'
#  'everymorning' 'everymorning' 'everymorning' 'everymorning'
#  'everymorning' 'everymorning' 'everymorning' 'everymorning'
#  'everymorning' 'everymorning' 'everymorning' 'everymorning'
#  'everymorning' 'everymorning' 'everymorning' 'everymorning'
#  'everymorning' 'everymorning' 'everymorning' 'everynight' 'everynight'
#  'everynight' 'everynight' 'everynight' 'everynight' 'everynight'
#  'everynight' 'everynight' 'everynight' 'everynight' 'everynight'
#  'everynight' 'everynight' 'everynight' 'everynight' 'everynight'
#  'everynight' 'everynight' 'everynight' 'everynight' 'gold' 'gold' 'gold'
#  'gold' 'gold' 'gold' 'gold' 'gold' 'gold' 'gold' 'gold' 'gold' 'gold'
#  'gold' 'gold' 'gold' 'gold' 'gold' 'gold' 'gold' 'gold' 'gold' 'gold'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'goodnight'
#  'goodnight' 'goodnight' 'goodnight' 'happy' 'happy' 'happy' 'happy'
#  'happy' 'happy' 'happy' 'happy' 'happy' 'happy' 'happy' 'happy' 'happy'
#  'happy' 'happy' 'happy' 'happy' 'happy' 'happy' 'happy' 'happy' 'happy'
#  'happy' 'happy' 'happy' 'happy' 'happy' 'happy' 'happy' 'happy' 'happy'
#  'happy' 'happy' 'happy' 'headache' 'headache' 'headache' 'headache'
#  'headache' 'headache' 'headache' 'headache' 'headache' 'headache'
#  'headache' 'headache' 'headache' 'headache' 'headache' 'headache'
#  'headache' 'headache' 'home' 'home' 'home' 'home' 'home' 'home' 'home'
#  'home' 'home' 'home' 'home' 'home' 'home' 'home' 'home' 'home' 'home'
#  'home' 'home' 'home' 'home' 'home' 'home' 'home' 'home' 'home' 'home'
#  'horse' 'horse' 'horse' 'horse' 'horse' 'horse' 'horse' 'horse' 'horse'
#  'horse' 'horse' 'horse' 'horse' 'horse' 'horse' 'horse' 'horse' 'horse'
#  'horse' 'horse' 'horse' 'horse' 'horse' 'horse' 'hot' 'hot' 'hot' 'hot'
#  'hot' 'hot' 'hot' 'hot' 'hot' 'hot' 'hot' 'hot' 'hot' 'hot' 'hot' 'hot'
#  'hot' 'hot' 'hot' 'hot' 'hot' 'hot' 'hot' 'hot' 'hot' 'hot' 'hot' 'hot'
#  'hot' 'hot' 'hot' 'hot' 'hot' 'hot' 'hot' 'hurt' 'hurt' 'hurt' 'hurt'
#  'hurt' 'hurt' 'hurt' 'hurt' 'hurt' 'hurt' 'hurt' 'hurt' 'hurt' 'hurt'
#  'hurt' 'hurt' 'hurt' 'hurt' 'hurt' 'itching' 'itching' 'itching'
#  'itching' 'itching' 'itching' 'itching' 'itching' 'itching' 'itching'
#  'itching' 'itching' 'itching' 'itching' 'itching' 'itching' 'itching'
#  'large' 'large' 'large' 'large' 'large' 'large' 'large' 'large' 'large'
#  'large' 'large' 'large' 'large' 'large' 'large' 'large' 'large' 'large'
#  'large' 'large' 'large' 'large' 'large' 'large' 'large' 'large' 'large'
#  'large' 'large' 'large' 'large' 'large' 'large' 'large' 'mom' 'mom' 'mom'
#  'mom' 'mom' 'mom' 'mom' 'mom' 'mom' 'mom' 'mom' 'mom' 'mom' 'mom' 'mom'
#  'mom' 'mom' 'mom' 'mom' 'mom' 'mom' 'mom' 'mom' 'mom' 'mom' 'mom' 'mom'
#  'mom' 'mom' 'mom' 'monthly' 'monthly' 'monthly' 'monthly' 'monthly'
#  'monthly' 'monthly' 'monthly' 'monthly' 'monthly' 'monthly' 'monthly'
#  'monthly' 'monthly' 'monthly' 'monthly' 'monthly' 'monthly' 'monthly'
#  'notfeelgood' 'notfeelgood' 'notfeelgood' 'notfeelgood' 'notfeelgood'
#  'notfeelgood' 'notfeelgood' 'notfeelgood' 'notfeelgood' 'notfeelgood'
#  'notfeelgood' 'notfeelgood' 'notfeelgood' 'notfeelgood' 'notfeelgood'
#  'notfeelgood' 'notfeelgood' 'notfeelgood' 'notfeelgood' 'notfeelgood'
#  'notfeelgood' 'notfeelgood' 'orange' 'orange' 'orange' 'orange' 'orange'
#  'orange' 'orange' 'orange' 'orange' 'orange' 'orange' 'orange' 'orange'
#  'orange' 'orange' 'orange' 'orange' 'orange' 'orange' 'orange' 'orange'
#  'pizza' 'pizza' 'pizza' 'pizza' 'pizza' 'pizza' 'pizza' 'pizza' 'pizza'
#  'pizza' 'pizza' 'pizza' 'pizza' 'pizza' 'pizza' 'pizza' 'pizza' 'pizza'
#  'pizza' 'pizza' 'pizza' 'pizza' 'pizza' 'please' 'please' 'please'
#  'please' 'please' 'please' 'please' 'please' 'please' 'please' 'please'
#  'please' 'please' 'please' 'please' 'please' 'please' 'please' 'please'
#  'please' 'please' 'please' 'please' 'please' 'please' 'please' 'please'
#  'shirt' 'shirt' 'shirt' 'shirt' 'shirt' 'shirt' 'shirt' 'shirt' 'shirt'
#  'shirt' 'shirt' 'shirt' 'shirt' 'shirt' 'shirt' 'shirt' 'shirt' 'shirt'
#  'shirt' 'shirt' 'shirt' 'shirt' 'shirt' 'shirt' 'shirt' 'shirt' 'shirt'
#  'soreness' 'soreness' 'soreness' 'soreness' 'swelling' 'swelling'
#  'swelling' 'swelling' 'swelling' 'swelling' 'swelling' 'swelling'
#  'swelling' 'swelling' 'swelling' 'swelling' 'swelling' 'swelling'
#  'swelling' 'swelling' 'swelling' 'swelling' 'swelling' 'swelling'
#  'takeliquidmedicine' 'takeliquidmedicine' 'takeliquidmedicine'
#  'takeliquidmedicine' 'takeliquidmedicine' 'takeliquidmedicine'
#  'takeliquidmedicine' 'takeliquidmedicine' 'takeliquidmedicine'
#  'takeliquidmedicine' 'takeliquidmedicine' 'takeliquidmedicine'
#  'takeliquidmedicine' 'takeliquidmedicine' 'takeliquidmedicine'
#  'takeliquidmedicine' 'takeliquidmedicine' 'takeliquidmedicine'
#  'takeliquidmedicine' 'thatsterrible' 'thatsterrible' 'thatsterrible'
#  'thatsterrible' 'thatsterrible' 'thatsterrible' 'thatsterrible'
#  'thatsterrible' 'thatsterrible' 'thatsterrible' 'thatsterrible'
#  'thatsterrible' 'thatsterrible' 'thatsterrible' 'thatsterrible'
#  'thatsterrible' 'thatsterrible' 'thatsterrible' 'thatsterrible'
#  'thatsterrible' 'tired' 'tired' 'tired' 'tired' 'tired' 'tired' 'tired'
#  'tired' 'tired' 'tired' 'tired' 'tired' 'tired' 'tired' 'tired' 'tired'
#  'tired' 'tired' 'tired' 'tired' 'upsetstomach' 'upsetstomach'
#  'upsetstomach' 'upsetstomach' 'upsetstomach' 'upsetstomach'
#  'upsetstomach' 'upsetstomach' 'upsetstomach' 'upsetstomach'
#  'upsetstomach' 'upsetstomach' 'upsetstomach' 'upsetstomach'
#  'upsetstomach' 'upsetstomach' 'upsetstomach' 'upsetstomach'
#  'upsetstomach' 'upsetstomach' 'upsetstomach' 'wash' 'wash' 'wash' 'wash'
#  'wash' 'wash' 'wash' 'wash' 'wash' 'wash' 'wash' 'wash' 'wash' 'wash'
#  'wash' 'wash' 'wash' 'wash' 'wash' 'wash' 'wash' 'wash' 'wash' 'wash'
#  'wash' 'wash' 'wash' 'wash' 'wash']
# Normalized matrix
# [4.85577038e-02 2.67134218e-02 2.44600475e-02 2.16799447e-02
#  2.05322363e-02 1.97711574e-02 1.90168295e-02 1.88917731e-02
#  1.77398784e-02 1.76919139e-02 1.66618812e-02 1.62221151e-02
#  1.58030941e-02 1.48711904e-02 1.45084790e-02 1.40877602e-02
#  1.38177201e-02 1.33440691e-02 1.31307947e-02 1.28031256e-02
#  1.26556014e-02 1.22890909e-02 1.18786076e-02 1.15740394e-02
#  1.13535557e-02 1.11092356e-02 1.07279515e-02 1.03447422e-02
#  1.01544443e-02 1.00134208e-02 9.89287951e-03 9.53359566e-03
#  9.46915507e-03 9.09343405e-03 8.98809616e-03 8.73639855e-03
#  8.59434029e-03 8.57243514e-03 8.44339962e-03 8.24069411e-03
#  8.12944350e-03 7.92592174e-03 7.74294687e-03 7.59086418e-03
#  7.38241737e-03 7.30157811e-03 7.07867877e-03 6.95932025e-03
#  6.86213658e-03 6.75261191e-03 6.70337213e-03 6.52126971e-03
#  6.45570637e-03 6.27598212e-03 6.13280021e-03 6.05220367e-03
#  5.99903074e-03 5.78237636e-03 5.70959358e-03 5.62350667e-03
#  5.55673963e-03 5.45436074e-03 5.36733599e-03 5.22362285e-03
#  5.16493996e-03 5.12895893e-03 5.03778918e-03 4.84227240e-03
#  4.77798077e-03 4.73318487e-03 4.55185201e-03 4.51818381e-03
#  4.38996958e-03 4.33552841e-03 4.25390102e-03 4.22477274e-03
#  4.14830831e-03 4.13273478e-03 3.99917706e-03 3.97267908e-03
#  3.88939091e-03 3.73733115e-03 3.62890526e-03 3.58720395e-03
#  3.56537154e-03 3.48992749e-03 3.37489633e-03 3.32136056e-03
#  3.24913853e-03 3.20205488e-03 3.14723228e-03 3.06919316e-03
#  3.03964032e-03 2.99407957e-03 2.93023642e-03 2.85341126e-03
#  2.82715479e-03 2.79739000e-03 2.70773308e-03 2.68437281e-03
#  2.67170273e-03 2.61314173e-03 2.53578880e-03 2.51503445e-03
#  2.48336230e-03 2.42064853e-03 2.34186171e-03 2.27638693e-03
#  2.22448687e-03 2.15451924e-03 2.13489762e-03 2.10385353e-03
#  2.09215055e-03 2.01594302e-03 1.99801127e-03 1.93668231e-03
#  1.88100047e-03 1.85657296e-03 1.84677680e-03 1.81496681e-03
#  1.78352525e-03 1.76272980e-03 1.72726673e-03 1.70070251e-03
#  1.68918242e-03 1.65723248e-03 1.63469537e-03 1.56491517e-03
#  1.53516930e-03 1.51684137e-03 1.48192271e-03 1.46677234e-03
#  1.41826829e-03 1.39626538e-03 1.37797639e-03 1.34272522e-03
#  1.33108112e-03 1.31419865e-03 1.27821535e-03 1.25557552e-03
#  1.21769087e-03 1.20528983e-03 1.18870090e-03 1.16222464e-03
#  1.12352677e-03 1.09593465e-03 1.06914330e-03 1.03059496e-03
#  1.01292929e-03 1.00138638e-03 9.84353403e-04 9.42561403e-04
#  9.30275318e-04 9.20450359e-04 9.09873943e-04 8.77244186e-04
#  8.65385776e-04 8.33758736e-04 8.27963567e-04 8.24920549e-04
#  8.06966015e-04 7.95246848e-04 7.81476944e-04 7.58206046e-04
#  7.37058806e-04 7.17940615e-04 7.00093770e-04 6.88513528e-04
#  6.66231746e-04 6.56269254e-04 6.51165316e-04 6.21179627e-04
#  6.12944596e-04 5.92654377e-04 5.80930861e-04 5.70419519e-04
#  5.51252426e-04 5.47260914e-04 5.18904063e-04 5.08858222e-04
#  4.89870143e-04 4.87143520e-04 4.76247421e-04 4.71520476e-04
#  4.59694710e-04 4.41214166e-04 4.35143122e-04 4.20460075e-04
#  4.13385283e-04 4.03600256e-04 3.96619065e-04 3.79815443e-04
#  3.75223477e-04 3.65721317e-04 3.63115856e-04 3.44522559e-04
#  3.35941699e-04 3.20221443e-04 3.15865523e-04 3.14535954e-04
#  2.98276942e-04 2.95859631e-04 2.94354958e-04 2.75641931e-04
#  2.70600077e-04 2.67658930e-04 2.61114296e-04 2.54155069e-04
#  2.45139847e-04 2.35891435e-04 2.31866204e-04 2.25377219e-04
#  2.18681862e-04 2.10786276e-04 2.00561050e-04 1.98512587e-04
#  1.91854679e-04 1.88271944e-04 1.84681504e-04 1.82895957e-04
#  1.77465803e-04 1.69794969e-04 1.66065390e-04 1.59378055e-04
#  1.56002294e-04 1.53027787e-04 1.48473679e-04 1.40023330e-04
#  1.38413769e-04 1.34089361e-04 1.29036016e-04 1.21732169e-04
#  1.16676785e-04 1.15225807e-04 1.08949794e-04 1.06821973e-04
#  1.03000162e-04 1.00622405e-04 9.48820224e-05 9.36544972e-05
#  8.72368489e-05 8.61343461e-05 8.30430450e-05 8.05956762e-05
#  7.60389685e-05 7.51136011e-05 7.24315644e-05 7.02703005e-05
#  6.55232239e-05 6.49591477e-05 6.34378426e-05 6.25160477e-05
#  5.95926776e-05 5.85149421e-05 5.66523776e-05 5.59951677e-05
#  5.47900676e-05 5.02054556e-05 4.86786218e-05 4.66173222e-05
#  4.63948357e-05 4.53837299e-05 4.30117583e-05 4.21977623e-05
#  3.94164820e-05 3.91781799e-05 3.76747776e-05 3.67588816e-05
#  3.57287657e-05 3.47864840e-05 3.30830376e-05 3.18355464e-05
#  3.15080971e-05 3.04213169e-05 2.85856444e-05 2.74155483e-05
#  2.70899225e-05 2.63811600e-05 2.53060744e-05 2.39347525e-05
#  2.25213806e-05 2.18135114e-05 2.11215122e-05 2.09477907e-05
#  2.01778670e-05 1.86437697e-05 1.84094540e-05 1.77299824e-05
#  1.71411526e-05 1.66398242e-05 1.64489237e-05 1.57851033e-05
#  1.45785046e-05 1.43792126e-05 1.37438310e-05 1.29245455e-05
#  1.24945251e-05 1.18778703e-05 1.15013151e-05 1.12801375e-05]
# [5.02879362 3.72991988 3.56913841 3.36018994 3.27003852 3.20886015
#  3.14705113 3.13668641 3.03955538 3.03544348 2.94575592 2.9066215
#  2.86883655 2.78296414 2.74881609 2.70866763 2.68258157 2.6362032
#  2.61505151 2.58221705 2.56729713 2.52984911 2.48723895 2.45514542
#  2.4316479  2.40534198 2.36370428 2.32110388 2.29965572 2.28363124
#  2.26984448 2.22824585 2.22070237 2.17619948 2.16355827 2.13304963
#  2.11563632 2.11293845 2.09697578 2.07165122 2.0576199  2.03170024
#  2.00811177 1.98829286 1.96080335 1.95003816 1.92004251 1.90378611
#  1.89044663 1.8752995  1.86844968 1.84289598 1.83360856 1.80790494
#  1.78716294 1.77538076 1.76756456 1.73535336 1.72439732 1.71134807
#  1.70115845 1.68541429 1.67191477 1.64937971 1.64008887 1.63436613
#  1.61977517 1.58803237 1.57745486 1.57004274 1.53967412 1.53396938
#  1.51204772 1.50264282 1.48843006 1.48332535 1.46984066 1.46707903
#  1.44317853 1.43838943 1.42323147 1.39513275 1.37474629 1.36682457
#  1.36265884 1.34816468 1.32576015 1.31520289 1.30082494 1.29136535
#  1.28026284 1.26429044 1.25818887 1.24872386 1.23533877 1.21903711
#  1.21341549 1.20701106 1.18751107 1.1823775  1.17958383 1.16658456
#  1.14918853 1.14447606 1.13724696 1.12279536 1.10437194 1.08882425
#  1.07634046 1.05927795 1.05444339 1.04674885 1.04383345 1.02464605
#  1.02007877 1.00430109 0.9897584  0.98331067 0.98071303 0.97223015
#  0.96377215 0.95813701 0.94845001 0.94112848 0.9379356  0.92902299
#  0.92268436 0.90277629 0.89415515 0.88880159 0.87851164 0.87400939
#  0.85943679 0.85274411 0.84714086 0.83623495 0.83260114 0.82730424
#  0.81589967 0.80864175 0.79634868 0.79228327 0.78681212 0.77800033
#  0.76493839 0.75548713 0.74619563 0.73261997 0.72631382 0.72216358
#  0.71599546 0.70063135 0.69605009 0.69236472 0.68837542 0.67591952
#  0.67133551 0.65895376 0.65665969 0.65545186 0.64827961 0.64355508
#  0.63795909 0.6283887  0.61956348 0.61147542 0.60382745 0.59881267
#  0.58904355 0.58462283 0.58234503 0.56877873 0.56499597 0.55556578
#  0.55004341 0.54504446 0.53580899 0.53386562 0.51985027 0.5147936
#  0.50509751 0.50368986 0.4980249  0.49554719 0.48929355 0.47935743
#  0.47604806 0.46794749 0.46399388 0.45846951 0.45448707 0.44475522
#  0.4420585  0.43642526 0.4348679  0.42358793 0.41827961 0.40837575
#  0.40558871 0.40473419 0.39413462 0.39253429 0.39153485 0.37888498
#  0.37540383 0.37335813 0.36876532 0.36381796 0.35730714 0.35050226
#  0.34749893 0.34260189 0.33747463 0.3313263  0.32319009 0.32153538
#  0.31609741 0.31313207 0.3101319  0.30862904 0.30401295 0.29737
#  0.29408597 0.28810381 0.28503634 0.28230586 0.27807342 0.27004426
#  0.2684877  0.26426029 0.25923296 0.25178939 0.2465057  0.24496815
#  0.2382034  0.23586584 0.23160807 0.22891913 0.22229347 0.22085084
#  0.2131497  0.21179852 0.20796314 0.20487578 0.1989999  0.19778531
#  0.19422211 0.1913025  0.18472785 0.18393099 0.18176445 0.18043904
#  0.17616969 0.17456941 0.17176861 0.17076939 0.16892178 0.16170007
#  0.15922229 0.15581469 0.15544243 0.15373928 0.14966779 0.14824479
#  0.14327607 0.14284231 0.14007483 0.1383617  0.13640923 0.13459843
#  0.13126152 0.12876294 0.12809903 0.12587044 0.12201374 0.11949045
#  0.11877872 0.11721459 0.11480139 0.11164755 0.10830095 0.10658535
#  0.1048811  0.1044489  0.10251145 0.09853752 0.09791635 0.09609237
#  0.09448323 0.0930913  0.09255577 0.09066892 0.08713472 0.08653709
#  0.08460356 0.08204316 0.08066676 0.07865096 0.07739421 0.07664643]

# %%
# Normalized, Butterworth, PCA to SVM
clf = SVC()
clf.fit(x_t_train, y_train)
print ('score', clf.score(x_t_test, y_test))
y_pred=clf.predict(x_t_test)
print ('pred label', y_pred)
print('length',len(clf.predict(x_t_test)))

# Confusion matrix
plot_confusion_matrix(clf, x_t_test, y_test,
                                 cmap=plt.cm.Blues)
plt.figure(figsize=(50,50))
plt.show()

#print(classification_report(y_test, y_pred, target_names=words))
pcaresults=classification_report(y_test, y_pred, target_names=words)
# Out:
# score 0.0784313725490196
# pred label ['happy' 'please' 'happy' 'goodnight' 'please' 'please' 'goodnight'
#  'please' 'please' 'happy' 'goodnight' 'please' 'everynight' 'please'
#  'goodnight' 'please' 'happy' 'goodnight' 'goodnight' 'please' 'please'
#  'please' 'please' 'please' 'please' 'please' 'happy' 'everynight' 'happy'
#  'goodnight' 'happy' 'please' 'goodnight' 'goodnight' 'please' 'happy'
#  'please' 'please' 'please' 'happy' 'happy' 'happy' 'please' 'please'
#  'happy' 'goodnight' 'please' 'everynight' 'happy' 'please' 'goodnight'
#  'goodnight' 'cost' 'please' 'please' 'goodnight' 'please' 'please'
#  'goodnight' 'goodnight' 'goodnight' 'goodnight' 'please' 'goodnight'
#  'happy' 'please' 'please' 'wash' 'goodnight' 'happy' 'please' 'please'
#  'happy' 'happy' 'happy' 'goodnight' 'please' 'please' 'happy' 'happy'
#  'please' 'happy' 'please' 'goodnight' 'wash' 'please' 'goodnight'
#  'goodnight' 'please' 'goodnight' 'goodnight' 'please' 'please' 'please'
#  'happy' 'please' 'happy' 'goodnight' 'cost' 'goodnight' 'happy' 'please'
#  'goodnight' 'please' 'please' 'please' 'please' 'please' 'please'
#  'please' 'goodnight' 'happy' 'goodnight' 'please' 'happy' 'goodnight'
#  'goodnight' 'goodnight' 'please' 'goodnight' 'please' 'please' 'please'
#  'please' 'please' 'please' 'happy' 'goodnight' 'happy' 'please'
#  'goodnight' 'please' 'please' 'please' 'goodnight' 'happy' 'please'
#  'please' 'goodnight' 'please' 'please' 'please' 'goodnight' 'please'
#  'please' 'please' 'everynight' 'please' 'please' 'goodnight' 'goodnight'
#  'happy' 'please' 'goodnight' 'goodnight' 'please' 'happy' 'goodnight'
#  'please' 'please' 'please' 'goodnight' 'goodnight' 'everynight' 'please'
#  'please' 'happy' 'happy' 'happy' 'goodnight' 'please' 'goodnight'
#  'please' 'goodnight' 'please' 'happy' 'goodnight' 'please' 'goodnight'
#  'happy' 'happy' 'goodnight' 'please' 'goodnight' 'please' 'happy'
#  'please' 'please' 'goodnight' 'happy' 'goodnight' 'goodnight' 'goodnight'
#  'happy' 'please' 'happy' 'goodnight' 'please' 'happy' 'please' 'please'
#  'please' 'goodnight' 'goodnight' 'goodnight' 'goodnight' 'cost' 'happy'
#  'happy' 'happy' 'happy' 'please' 'goodnight' 'please' 'goodnight'
#  'please' 'goodnight' 'please' 'happy' 'please' 'please' 'happy' 'please'
#  'please' 'please' 'goodnight' 'dollar' 'happy' 'happy' 'please' 'please'
#  'happy' 'please' 'everynight' 'please' 'happy' 'please' 'goodnight'
#  'happy' 'goodnight' 'goodnight' 'please' 'day' 'please' 'please' 'please'
#  'goodnight' 'goodnight' 'please' 'please' 'goodnight' 'goodnight'
#  'please' 'please' 'happy' 'please' 'goodnight' 'please' 'please'
#  'goodnight' 'happy' 'dollar' 'wash' 'please' 'wash' 'happy' 'please'
#  'happy' 'please' 'please' 'goodnight' 'please' 'please' 'please' 'please'
#  'happy' 'please' 'please' 'goodnight' 'happy' 'please' 'please' 'cost'
#  'please' 'please' 'please' 'please' 'please' 'happy' 'please' 'please'
#  'happy' 'please' 'please' 'please' 'please' 'goodnight' 'goodnight'
#  'please' 'please' 'please' 'please' 'happy' 'goodnight' 'goodnight'
#  'please' 'goodnight' 'please' 'please' 'goodnight' 'everynight' 'please'
#  'happy' 'please' 'goodnight' 'please' 'please' 'goodnight' 'please'
#  'goodnight' 'happy' 'happy' 'please' 'goodnight' 'please' 'please'
#  'please' 'goodnight' 'please' 'please' 'please' 'please' 'goodnight'
#  'goodnight' 'goodnight' 'please' 'goodnight' 'happy' 'goodnight' 'please'
#  'please' 'please' 'happy' 'please' 'happy' 'goodnight' 'goodnight'
#  'please' 'please' 'please' 'please' 'happy' 'please' 'goodnight' 'please'
#  'please' 'please' 'goodnight' 'please' 'please' 'goodnight' 'please'
#  'happy' 'please' 'happy' 'goodnight' 'please' 'please' 'please' 'happy'
#  'goodnight' 'goodnight' 'please' 'happy' 'goodnight' 'please' 'cost'
#  'happy' 'please' 'please' 'goodnight' 'please' 'please' 'please'
#  'goodnight' 'happy' 'goodnight' 'happy' 'please' 'goodnight' 'goodnight'
#  'please' 'please' 'goodnight' 'please' 'please' 'please' 'goodnight'
#  'goodnight' 'please' 'please' 'happy' 'day' 'happy' 'please' 'goodnight'
#  'please' 'please' 'goodnight' 'happy' 'goodnight' 'goodnight' 'please'
#  'happy' 'please' 'happy' 'goodnight' 'goodnight' 'please' 'please'
#  'goodnight' 'please' 'please' 'please' 'happy' 'happy' 'goodnight'
#  'please' 'please' 'everynight' 'please' 'please' 'goodnight' 'happy'
#  'please' 'please' 'please' 'happy' 'please' 'please' 'happy' 'goodnight'
#  'please' 'please' 'day' 'please' 'please' 'please' 'goodnight' 'please'
#  'happy' 'please' 'please' 'goodnight' 'please' 'happy' 'happy'
#  'goodnight' 'happy' 'wash' 'wash' 'goodnight' 'please' 'please' 'happy'
#  'please' 'please' 'please' 'goodnight' 'happy' 'happy' 'please'
#  'goodnight' 'please' 'please' 'please' 'goodnight' 'please' 'goodnight'
#  'please' 'please' 'please' 'please' 'goodnight' 'please' 'please' 'happy'
#  'please' 'happy' 'goodnight' 'goodnight' 'please' 'please' 'everynight'
#  'please' 'please' 'please' 'please' 'please' 'goodnight' 'happy' 'happy'
#  'please' 'happy' 'happy' 'goodnight' 'please' 'please' 'please' 'please']
# length 510
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Summary of results**

# %%
print('Directly:')
print(directresults)
print('Normalized:')
print(normresults)
print('Butterworth:')
print(butterresults)
print('PCA:')
print(pcaresults)
# Out:
# Directly:
#                        precision    recall  f1-score   support
#
#            allmorning       0.00      0.00      0.00        11
#                  bird       0.00      0.00      0.00        16
#                  blue       0.00      0.00      0.00        20
#             cantsleep       0.00      0.00      0.00        13
#                   cat       0.00      0.00      0.00        16
#         coldrunnynose       0.00      0.00      0.00        14
# continuouslyforanhour       0.00      0.00      0.00        12
#                  cost       0.29      0.12      0.17        17
#                   day       0.00      0.00      0.00        19
#                dollar       0.00      0.00      0.00        17
#          everymorning       0.00      0.00      0.00        12
#            everynight       0.00      0.00      0.00        15
#                  gold       0.00      0.00      0.00         9
#             goodnight       0.08      0.38      0.13        16
#                 happy       0.00      0.00      0.00        25
#              headache       0.00      0.00      0.00        12
#                  home       0.00      0.00      0.00        14
#                 horse       0.00      0.00      0.00        17
#                   hot       0.06      0.83      0.11        18
#                  hurt       0.00      0.00      0.00         8
#               itching       0.00      0.00      0.00        11
#                 large       0.08      0.44      0.14        18
#                   mom       0.00      0.00      0.00        16
#               monthly       0.00      0.00      0.00         9
#           notfeelgood       0.00      0.00      0.00        15
#                orange       0.00      0.00      0.00        14
#                 pizza       0.00      0.00      0.00        14
#                please       0.00      0.00      0.00        18
#                 shirt       0.16      0.80      0.27        15
#              soreness       0.00      0.00      0.00         4
#              swelling       0.00      0.00      0.00        12
#    takeliquidmedicine       0.00      0.00      0.00        11
#         thatsterrible       0.00      0.00      0.00        10
#                 tired       0.00      0.00      0.00        11
#          upsetstomach       0.00      0.00      0.00         9
#                  wash       0.00      0.00      0.00        22
#
#              accuracy                           0.08       510
#             macro avg       0.02      0.07      0.02       510
#          weighted avg       0.02      0.08      0.03       510
#
# Normalized:
#                        precision    recall  f1-score   support
#
#            allmorning       0.00      0.00      0.00        10
#                  bird       0.00      0.00      0.00        17
#                  blue       0.06      0.89      0.11        18
#             cantsleep       0.00      0.00      0.00        12
#                   cat       0.00      0.00      0.00        10
#         coldrunnynose       0.00      0.00      0.00        11
# continuouslyforanhour       0.00      0.00      0.00         9
#                  cost       0.06      0.69      0.12        16
#                   day       0.00      0.00      0.00        15
#                dollar       0.00      0.00      0.00        21
#          everymorning       0.00      0.00      0.00        11
#            everynight       0.00      0.00      0.00        14
#                  gold       0.00      0.00      0.00        16
#             goodnight       0.00      0.00      0.00        21
#                 happy       0.16      0.20      0.18        20
#              headache       0.00      0.00      0.00         9
#                  home       0.00      0.00      0.00        20
#                 horse       0.00      0.00      0.00        12
#                   hot       0.00      0.00      0.00        21
#                  hurt       0.00      0.00      0.00        11
#               itching       0.00      0.00      0.00         9
#                 large       0.10      0.22      0.14        18
#                   mom       0.00      0.00      0.00        21
#               monthly       0.00      0.00      0.00        14
#           notfeelgood       0.00      0.00      0.00        17
#                orange       0.00      0.00      0.00        13
#                 pizza       0.00      0.00      0.00        14
#                please       0.00      0.00      0.00        16
#                 shirt       0.00      0.00      0.00        20
#              soreness       0.00      0.00      0.00         3
#              swelling       0.00      0.00      0.00         9
#    takeliquidmedicine       0.00      0.00      0.00        13
#         thatsterrible       0.00      0.00      0.00        13
#                 tired       0.00      0.00      0.00         9
#          upsetstomach       0.00      0.00      0.00        11
#                  wash       0.00      0.00      0.00        16
#
#              accuracy                           0.07       510
#             macro avg       0.01      0.06      0.02       510
#          weighted avg       0.01      0.07      0.02       510
#
# Butterworth:
#                        precision    recall  f1-score   support
#
#            allmorning       0.00      0.00      0.00        12
#                  bird       0.00      0.00      0.00        13
#                  blue       0.00      0.00      0.00        22
#             cantsleep       0.00      0.00      0.00        13
#                   cat       0.00      0.00      0.00        13
#         coldrunnynose       0.00      0.00      0.00        13
# continuouslyforanhour       0.00      0.00      0.00        13
#                  cost       0.00      0.00      0.00        19
#                   day       0.00      0.00      0.00        13
#                dollar       0.05      0.06      0.06        16
#          everymorning       0.00      0.00      0.00        16
#            everynight       0.00      0.00      0.00        10
#                  gold       0.00      0.00      0.00        12
#             goodnight       0.05      1.00      0.09        19
#                 happy       0.00      0.00      0.00        21
#              headache       0.00      0.00      0.00        12
#                  home       0.00      0.00      0.00        17
#                 horse       0.00      0.00      0.00        13
#                   hot       0.00      0.00      0.00        24
#                  hurt       0.00      0.00      0.00        13
#               itching       0.00      0.00      0.00         7
#                 large       0.00      0.00      0.00        22
#                   mom       0.00      0.00      0.00        18
#               monthly       0.00      0.00      0.00         8
#           notfeelgood       0.00      0.00      0.00        14
#                orange       0.00      0.00      0.00        14
#                 pizza       0.00      0.00      0.00        12
#                please       0.00      0.00      0.00        19
#                 shirt       0.05      0.44      0.09         9
#              soreness       0.00      0.00      0.00         4
#              swelling       0.00      0.00      0.00        10
#    takeliquidmedicine       0.00      0.00      0.00        12
#         thatsterrible       0.00      0.00      0.00        12
#                 tired       0.00      0.00      0.00        13
#          upsetstomach       0.00      0.00      0.00        11
#                  wash       0.00      0.00      0.00        21
#
#              accuracy                           0.05       510
#             macro avg       0.00      0.04      0.01       510
#          weighted avg       0.00      0.05      0.01       510
#
# PCA:
#                        precision    recall  f1-score   support
#
#            allmorning       0.00      0.00      0.00        15
#                  bird       0.00      0.00      0.00        14
#                  blue       0.00      0.00      0.00        21
#             cantsleep       0.00      0.00      0.00        14
#                   cat       0.00      0.00      0.00        18
#         coldrunnynose       0.00      0.00      0.00         9
# continuouslyforanhour       0.00      0.00      0.00        13
#                  cost       0.40      0.10      0.16        20
#                   day       0.00      0.00      0.00        12
#                dollar       0.00      0.00      0.00        18
#          everymorning       0.00      0.00      0.00        10
#            everynight       0.11      0.11      0.11         9
#                  gold       0.00      0.00      0.00        16
#             goodnight       0.08      0.69      0.15        16
#                 happy       0.14      0.74      0.24        19
#              headache       0.00      0.00      0.00        13
#                  home       0.00      0.00      0.00        15
#                 horse       0.00      0.00      0.00        16
#                   hot       0.00      0.00      0.00        22
#                  hurt       0.00      0.00      0.00        11
#               itching       0.00      0.00      0.00         9
#                 large       0.00      0.00      0.00        23
#                   mom       0.00      0.00      0.00        17
#               monthly       0.00      0.00      0.00        14
#           notfeelgood       0.00      0.00      0.00        14
#                orange       0.00      0.00      0.00        17
#                 pizza       0.00      0.00      0.00        11
#                please       0.05      0.86      0.09        14
#                 shirt       0.00      0.00      0.00        16
#              soreness       0.00      0.00      0.00         1
#              swelling       0.00      0.00      0.00        11
#    takeliquidmedicine       0.00      0.00      0.00        10
#         thatsterrible       0.00      0.00      0.00        11
#                 tired       0.00      0.00      0.00        11
#          upsetstomach       0.00      0.00      0.00        13
#                  wash       0.00      0.00      0.00        17
#
#              accuracy                           0.08       510
#             macro avg       0.02      0.07      0.02       510
#          weighted avg       0.03      0.08      0.02       510

# %% [markdown]
# TODO:
#
# -check what happens when combining diff data sources
#
# -graph components
#
# find correlations
#
# -interpret pca results
#
# -try pca per individual/word
#
# -read dataset papers
#
# correlation component with word
#
# -try straight to svm
#
# -resend email
#
# check what is the data
#
# -merge timeseries word index
#
# see how stable each feature are
#
# standard deviation timeseries
#
# -try without filter
#
# multi-class classifier SVM
#
# **try with 2 words, only emg
# average per column
# test each step
# test svm with 2 matrices
# see if svm has access to test set
# maybe shifted per set

# %% [markdown]
# https://www.researchgate.net/publication/303707429_Combining_Smartphone_and_Smartwatch_Sensor_Data_in_Activity_Recognition_Approaches_an_Experimental_Evaluation

# %% [markdown]
# References
#
# https://stackoverflow.com/questions/56449262/how-to-upload-folders-to-google-colab
#
# https://github.com/datarail/datarail/issues/39
#
# https://dbader.org/blog/python-check-if-file-exists
#
# https://datacarpentry.org/python-socialsci/11-joins/index.html
#
# https://stackoverflow.com/questions/26414913/normalize-columns-of-pandas-data-frame
#
# https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html
#
# https://towardsdatascience.com/pca-using-python-scikit-learn-e653f8989e60
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html
#
# https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm
#
# https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.signal.butter.html
#
# https://stackoverflow.com/questions/32194967/how-to-do-pca-and-svm-for-classification-in-python
#
# https://stackoverflow.com/questions/6822725/rolling-or-sliding-window-iterator
#
# https://scikit-learn.org/stable/modules/cross_validation.html
#
# https://stackoverflow.com/questions/47684606/merge-cells-with-pandas
#
# https://scientificallysound.org/2016/08/18/python-analysing-emg-signals-part-3/
#
# https://stackoverflow.com/questions/58374492/python-valueerror-the-length-of-the-input-vector-x-must-be-greater-than-padle
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.set_index.html
#
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
#
# https://statinfer.com/204-4-2-calculating-sensitivity-and-specificity-in-python/
#
# https://www.datacamp.com/community/tutorials/pandas-multi-index
#
# https://www.geeksforgeeks.org/how-to-get-rows-index-names-in-pandas-dataframe/
#
# https://stackoverflow.com/questions/28140771/select-only-one-index-of-multiindex-dataframe
#
# https://www.educative.io/edpresso/how-to-create-a-confusion-matrix-in-python-using-scikit-learn
#
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html
#
# http://www.datasciencemadesimple.com/standard-deviation-function-python-pandas-row-column/
#
# https://stackoverflow.com/questions/39047915/concat-series-onto-dataframe-with-column-name

# %%
"""
### Combine all files
words=['allmorning', 'bird', 'blue', 'cantsleep', 'cat', 'coldrunnynose', 'continuouslyforanhour', 'cost', 'day', 'dollar', 'everymorning', 'everynight', 'gold', 'goodnight', 'happy', 'headache', 'home', 'horse', 'hot', 'hurt', 'itching', 'large', 'mom', 'monthly', 'notfeelgood', 'orange', 'pizza', 'please', 'shirt', 'soreness', 'swelling', 'takeliquidmedicine', 'thatsterrible', 'tired', 'upsetstomach', 'wash']
lengths=np.zeros(849, dtype=int)
reps=np.zeros(36,dtype=int)
wordnum=-1
counter=0

for w in words:
  repcount=0
  wordnum+=1

  for i in range (10, 120):
    path='/content/2MyoASL/' + w + '_' + str(i) + '.csv'

    if os.path.exists(path)==True:
      counter+=1
      repcount+=1
      trial=pd.read_csv(path)
      lengths[counter-1]=len(trial)
      
      # Replace counter with evaluated term
      for r in range(0,len(trial)):
        trial.iloc[r,0]=wordnum
        
      # Combine all trials
      if path=='/content/2MyoASL/allmorning_10.csv':
          matrix=trial
          
          # Create plot for EMG

          # Create plot for accelerometer
          plt.figure()
          alx=plt.axes(projection='3d')
          alx.plot3D(trial.loc[:, 'AXL'].values, trial.loc[:, 'AYL'].values, trial.loc[:, 'AZL'].values)
          alx.set_title('Accelerometer on left arm')

          plt.figure()
          arx=plt.axes(projection='3d')
          arx.plot3D(trial.loc[:, 'AXR'].values, trial.loc[:, 'AYR'].values, trial.loc[:, 'AZR'].values)
          arx.set_title('Accelerometer on right arm')

          # Create plot for gyroscope
          plt.figure()
          glx=plt.axes(projection='3d')
          glx.plot3D(trial.loc[:, 'GXL'].values, trial.loc[:, 'GYL'].values, trial.loc[:, 'GZL'].values)
          glx.set_title('Gyroscope on left arm')

          plt.figure()
          grx=plt.axes(projection='3d')
          grx.plot3D(trial.loc[:, 'GXR'].values, trial.loc[:, 'GYR'].values, trial.loc[:, 'GZR'].values)
          grx.set_title('Gyroscope on right arm')
      else:
          matrix=pd.concat([matrix, trial])

          ###############################################
          # Create plot for accelerometer
          alx.plot3D(trial.loc[:, 'AXL'].values, trial.loc[:, 'AYL'].values, trial.loc[:, 'AZL'].values)
          arx.plot3D(trial.loc[:, 'AXR'].values, trial.loc[:, 'AYR'].values, trial.loc[:, 'AZR'].values)
          #plt.show()

          # Create plot for gyroscope
          glx.plot3D(trial.loc[:, 'GXL'].values, trial.loc[:, 'GYL'].values, trial.loc[:, 'GZL'].values)
          grx.plot3D(trial.loc[:, 'GXR'].values, trial.loc[:, 'GYR'].values, trial.loc[:, 'GZR'].values)
          ###############################################

  reps[wordnum]=repcount
plt.show()
"""
# Out:
# "\n### Combine all files\nwords=['allmorning', 'bird', 'blue', 'cantsleep', 'cat', 'coldrunnynose', 'continuouslyforanhour', 'cost', 'day', 'dollar', 'everymorning', 'everynight', 'gold', 'goodnight', 'happy', 'headache', 'home', 'horse', 'hot', 'hurt', 'itching', 'large', 'mom', 'monthly', 'notfeelgood', 'orange', 'pizza', 'please', 'shirt', 'soreness', 'swelling', 'takeliquidmedicine', 'thatsterrible', 'tired', 'upsetstomach', 'wash']\nlengths=np.zeros(849, dtype=int)\nreps=np.zeros(36,dtype=int)\nwordnum=-1\ncounter=0\n\nfor w in words:\n  repcount=0\n  wordnum+=1\n\n  for i in range (10, 120):\n    path='/content/2MyoASL/' + w + '_' + str(i) + '.csv'\n\n    if os.path.exists(path)==True:\n      counter+=1\n      repcount+=1\n      trial=pd.read_csv(path)\n      lengths[counter-1]=len(trial)\n      \n      # Replace counter with evaluated term\n      for r in range(0,len(trial)):\n        trial.iloc[r,0]=wordnum\n        \n      # Combine all trials\n      if path=='/content/2MyoASL/allmorning_10.csv':\n          matrix=trial\n          \n          # Create plot for EMG\n\n          # Create plot for accelerometer\n          plt.figure()\n          alx=plt.axes(projection='3d')\n          alx.plot3D(trial.loc[:, 'AXL'].values, trial.loc[:, 'AYL'].values, trial.loc[:, 'AZL'].values)\n          alx.set_title('Accelerometer on left arm')\n\n          plt.figure()\n          arx=plt.axes(projection='3d')\n          arx.plot3D(trial.loc[:, 'AXR'].values, trial.loc[:, 'AYR'].values, trial.loc[:, 'AZR'].values)\n          arx.set_title('Accelerometer on right arm')\n\n          # Create plot for gyroscope\n          plt.figure()\n          glx=plt.axes(projection='3d')\n          glx.plot3D(trial.loc[:, 'GXL'].values, trial.loc[:, 'GYL'].values, trial.loc[:, 'GZL'].values)\n          glx.set_title('Gyroscope on left arm')\n\n          plt.figure()\n          grx=plt.axes(projection='3d')\n          grx.plot3D(trial.loc[:, 'GXR'].values, trial.loc[:, 'GYR'].values, trial.loc[:, 'GZR'].values)\n          grx.set_title('Gyroscope on right arm')\n      else:\n          matrix=pd.concat([matrix, trial])\n\n          ###############################################\n          # Create plot for accelerometer\n          alx.plot3D(trial.loc[:, 'AXL'].values, trial.loc[:, 'AYL'].values, trial.loc[:, 'AZL'].values)\n          arx.plot3D(trial.loc[:, 'AXR'].values, trial.loc[:, 'AYR'].values, trial.loc[:, 'AZR'].values)\n          #plt.show()\n\n          # Create plot for gyroscope\n          glx.plot3D(trial.loc[:, 'GXL'].values, trial.loc[:, 'GYL'].values, trial.loc[:, 'GZL'].values)\n          grx.plot3D(trial.loc[:, 'GXR'].values, trial.loc[:, 'GYR'].values, trial.loc[:, 'GZR'].values)\n          ###############################################\n\n  reps[wordnum]=repcount\nplt.show()\n"

# %%
"""
# PCA for normmatrix
pca = PCA(n_components=35)
comp=pca.fit_transform(norm_matrix_eago)
principal=pd.DataFrame(data=comp, columns=['PC 0', 'PC 1', 'PC 2', 'PC 3', 'PC 4', 'PC 5', 'PC 6', 'PC 7', 'PC 8', 'PC 9', 'PC 10', 
                                           'PC 11', 'PC 12', 'PC 13', 'PC 14', 'PC 16', 'PC 17', 'PC 18', 'PC 19', 'PC 20', 
                                           'PC 21', 'PC 22', 'PC 23', 'PC 24', 'PC 25', 'PC 26', 'PC 27', 'PC 28', 'PC 29', 
                                           'PC 30', 'PC 31', 'PC 32', 'PC 33', 'PC 34', 'PC35'])
#principal.reset_index(drop=True, inplace=True)
#norm_matrix_eago[['Counter']].reset_index(drop=True, inplace=True)
norm_matrix_eago.reset_index(drop=True, inplace=True)
m.reset_index(drop=True, inplace=True)
#finaldf=pd.join([principal, norm_matrix_eago[['Counter']]], axis=1, ignore_index=True).reset_index()
finaldf=principal.join(m[['Counter']],how='outer')
finaldf=finaldf.drop(columns=['PC 0'])
####finaldf=principal
####print(m['Counter'])
####finaldf['Word']=m['Counter']
#finaldf=pd.concat([principal,norm_matrix_eago[['Counter']]], axis=1, ignore_index=True)

print("Normalized matrix")
print(pca.explained_variance_ratio_)
print(pca.singular_values_)
plt.figure()
plt.bar(fn,pca.explained_variance_ratio_)
plt.show()
plt.bar(fn,pca.singular_values_)
plt.show()
print(finaldf)
#print(principal.join(norm_matrix_eago[['Counter']],how='inner'))
"""
"""
# PCA for normalizedmatrix
pca = PCA(n_components=34)
pca.fit(normalized_matrix)
print("Normalized features")
print(pca.explained_variance_ratio_)
print(pca.singular_values_)
plt.figure()
plt.bar(fn[0:34],pca.explained_variance_ratio_)
plt.show()
plt.bar(fn[0:34],pca.singular_values_)
plt.show()

# PCA for standardizedmatrix
pca = PCA(n_components=34)
pca.fit(standardized_matrix)
print("Standardized features")
print(pca.explained_variance_ratio_)
print(pca.singular_values_)
plt.figure()
plt.bar(fn[0:34],pca.explained_variance_ratio_)
plt.show()
plt.bar(fn[0:34],pca.singular_values_)
plt.show()
"""
# Out:
# '\n# PCA for normalizedmatrix\npca = PCA(n_components=34)\npca.fit(normalized_matrix)\nprint("Normalized features")\nprint(pca.explained_variance_ratio_)\nprint(pca.singular_values_)\nplt.figure()\nplt.bar(fn[0:34],pca.explained_variance_ratio_)\nplt.show()\nplt.bar(fn[0:34],pca.singular_values_)\nplt.show()\n\n# PCA for standardizedmatrix\npca = PCA(n_components=34)\npca.fit(standardized_matrix)\nprint("Standardized features")\nprint(pca.explained_variance_ratio_)\nprint(pca.singular_values_)\nplt.figure()\nplt.bar(fn[0:34],pca.explained_variance_ratio_)\nplt.show()\nplt.bar(fn[0:34],pca.singular_values_)\nplt.show()\n'
